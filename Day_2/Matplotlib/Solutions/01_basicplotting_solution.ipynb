# %% [markdown]
# # Matplotlib Basics
# Most of the Matplotlib utilities lies under the pyplot submodule, and are usually imported under the plt alias:

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# using the pyplot submodule and numpy, we can now generate simple plots!

# %%
import numpy as np

xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# Right now this code plots the two points (of which the coordinates (0,0) and (6,250) are specified in the two arrays xpoints and ypoints), which are connected via a line. If we want to make it more clear that we are actually only plotting single points, we can specify the type of line that is produced in the plot:

# %%
xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints, 'o')
plt.show()

# %% [markdown]
# Your turn: Create a plot of the points (1,4), (-2,8), (8,10), (11,5). First plot the points connected by a line and then plot the single points.

# %%
xcoords = np.array([1,-2, 8, 11])
ycoords = np.array([4,8,10,5])

plt.plot(xcoords, ycoords)
plt.show()

plt.plot(xcoords, ycoords, 'o')
plt.show()

# %% [markdown]
# Now try running the same code. This time, do not specify the xpoints (just run plt.plot(ypoints)). What changed?

# %%
plt.plot(ycoords)
plt.show()

# %% [markdown]
# In the code above, we have specified that we only want to see the points that we are plotting (without the line connecting them) by running:
#
# plt.plot(xpoints, ypoints, 'o')
#
# But what does the term 'o' actually do? The plot function can produce very customizable outcomes. Using different arguments, we can change among others the linestyle of our lines, the marker that marks the points or the markersize we want.
#
# All of these arguments are specified in the documentation of matplotlib: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html
#
# Your turn: Create a plot of the same points you plotted before. This time, check out the documentation and create a plot that has a red, dotted line with stars marking the points.

# %%
plt.plot(xcoords, ycoords, c='red', ls='dotted', marker = '*')
plt.show()

# %% [markdown]
# There are many other ways in which plots can be customized. We can add legends, titles, axis names and much more.
#
# We can add such features by adding different commands to our plotting code:
#
# plt.plot(xcoords, ycoords)
#
#
# plt.title("Some random plot")
#
#
# plt.show()
#
# Play around with this a bit! Try to add a title, and axis names to the plot you created. Check the documentation if you do not know which command to use (https://matplotlib.org/stable/api/pyplot_summary.html).

# %%
plt.plot(xcoords,ycoords)
plt.title("Some random plot")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()
