# %% [markdown]
# # Artists
#
# Now that you have learned about the basic plotting functions of matplotlib, we will move on to more advanced ways to think about plots.
#
# In matplotlib whenever we plot something, we create a "Figure". You can think of a figure as the empty canvas that you draw your plots onto. Onto a Figure, we can draw plots using the "Axes" functionality. Each "Ax" that we put into a Figure can have different characteristics.

# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
data = np.random.normal(-20, 15, 500) # this code creates numbers in a normal distribution with the mean = -20, the standard deviation = 15 and the size of the data being 500 datapoints

fig, ax = plt.subplots()
#with this command we create a figure and add an ax
ax.hist(data, bins= 200)
plt.show()

# %% [markdown]
# ### Subplots
#
# The function plt.subplots enables us to create multiple artists in a single figure. When we work with such artists, we can also add titles to our subplots and to the axes of these plots. The commands for this are a bit different than with the simple plotting functionality you were introduced to earlier. For instance, when we want to add titles to the below subplots, we can use "ax.set_title("Title") instead of plt.title("Title")

# %%
data2 = np.random.normal(0, 15, 500)

fig, (ax1, ax2) = plt.subplots(2, sharex=True)
ax1.hist(data, bins= 200, color='orange')
ax2.hist(data2, bins = 200)
plt.show()

# the same is also possible in a different way
fig, axs = plt.subplots(2, sharex=True)
axs[0].hist(data, bins= 200, color='red')
axs[1].hist(data2, bins = 200)
plt.show()

# Notice how the plots are in different figures, meaning on a different canvas, each time we create a figure and show it

# %%
fig, (ax1, ax2) = plt.subplots(2, sharex=True)
ax1.hist(data, bins= 200, color='orange')
ax1.set_title("Data")
ax2.hist(data2, bins = 200)
ax2.set_title("Data2")
plt.show()

# %% [markdown]
# Using this functionality, we can create figures with multiple subplots in them. And we can structure these figures however we like by using the indexing functionality of python.
#
# Your turn: Create a figure with 3 plots.
# 1) One large plot on the left side should show the points of "data" and "data2" in a scatterplot, set the alpha value of the scatterplot to 0,5 (https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html).
# 2) On the right side, plot the histograms for "data":top and "data2":bottom
#
# To achieve the uneven distribution of subplots you might want to refer to: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.subplot.html
#
# Use the tight_layout function to adjust the padding between the subplots (https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.tight_layout.html). To see the effect of the function, you can plot the figure without using it.
#
# Adjust the color scheme and plot titles to make it clear what data the plots represent.
#
# Tip: As this plot is more complex than the ones before, it might be easier to write the code for it in smaller steps. Try to first create the single plots, then put them together in a single figure and then adjust the figure to your liking.

# %%
fig= plt.figure()

ax1 = plt.subplot(121)
ax2 = plt.subplot(222)
ax3 = plt.subplot(224)

ax1.scatter(data, data2, alpha = 0.5)
ax1.set_title("Data vs Data2")
ax2.hist(data, color = "orange")
ax2.set_title("Data")
ax3.hist(data2)
ax3.set_title("Data2")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Saving Figures
#
# Once we created our plots, it might be useful for us to save them. In VSCode, we can save plots by just finding the "Save As" Icon (usually to the right of the plot when you hover over it with your cursor).
# Of course, python also allows you to save plots with code.
#
# plt.savefig allows you to save the current figure: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.savefig.html
#
# Your turn: Save the figure from before using savefig.

# %%
fig= plt.figure()

ax1 = plt.subplot(121)
ax2 = plt.subplot(222)
ax3 = plt.subplot(224)

ax1.scatter(data, data2, alpha = 0.5)
ax1.set_title("Data vs Data2")
ax2.hist(data, color = "orange")
ax2.set_title("Data")
ax3.hist(data2)
ax3.set_title("Data2")

plt.tight_layout()
plt.savefig("3plots.png")
plt.show()

# %% [markdown]
# Bonus exercise: Recreate the last plot from the basic plotting exercise as a figure with one artist.

# %%
xcoords = np.array([1,-2, 8, 11])
ycoords = np.array([4,8,10,5])

fig, ax = plt.subplots(1)
ax.plot(xcoords, ycoords, c='red', ls='dotted', marker = '*')
ax.set_title("Some random plot")
ax.set_xlabel("X")
ax.set_ylabel("Y")
plt.show()
